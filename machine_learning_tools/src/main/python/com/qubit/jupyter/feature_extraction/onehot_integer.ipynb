# %%
import pandas as pd

demo_df = pd.DataFrame({'Integer-Merkmal': [0,1,2,1],
                       'Kategorisches Merkmal':['socks','fox','socks','box']})

demo_df.head()
# Out:
#    Integer-Merkmal Kategorisches Merkmal
# 0                0                 socks
# 1                1                   fox
# 2                2                 socks
# 3                1                   box

# %%
demo_dummies = pd.get_dummies(demo_df)
demo_dummies.head()
# Out:
#    Integer-Merkmal  Kategorisches Merkmal_box  Kategorisches Merkmal_fox  \
# 0                0                          0                          0
# 1                1                          0                          1
# 2                2                          0                          0
# 3                1                          1                          0
#
#    Kategorisches Merkmal_socks
# 0                            1
# 1                            0
# 2                            1
# 3                            0

# %%
demo_df['Integer-Merkmal'] = demo_df['Integer-Merkmal'].astype(str)
demo_dummies = pd.get_dummies(demo_df)
demo_dummies.head()
# Out:
#    Integer-Merkmal_0  Integer-Merkmal_1  Integer-Merkmal_2  \
# 0                  1                  0                  0
# 1                  0                  1                  0
# 2                  0                  0                  1
# 3                  0                  1                  0
#
#    Kategorisches Merkmal_box  Kategorisches Merkmal_fox  \
# 0                          0                          0
# 1                          0                          1
# 2                          0                          0
# 3                          1                          0
#
#    Kategorisches Merkmal_socks
# 0                            1
# 1                            0
# 2                            1
# 3                            0
